# %% [markdown]
# # Sample Size

# %%
import pandas as pd
import os

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## CPV2010 data extraction

# %%
# Read 2015 and 2010 csv files and extract Metropolis
ZM_2015 = pd.read_csv("D:\Tesis\Datos\Zonas metropolitanas\ZM_2015.csv", encoding='latin-1', usecols=list(range(7)))

# %%
# Columns to take from Censo de Población y Vivienda
cpyv_col = [0,2] + list(range(4,12)) + [29,32,35,38,41,44,26,48,54] + [108,129] + \
            [132,135,138,141] + list(range(157,165)) + [171,172] + list(range(189,198))

# Read Censo de Población y Vivienda files
CPV_path = 'D:/Tesis/Datos/Censo Poblacion y Vivienda 2010/AGEB/conjunto_de_datos'

# Locate filenames
CPV_files = []
for r, d, f in os.walk(CPV_path):
    for file in f:
        CPV_files.append(os.path.join(r, file))

# Put all csv files in a list to concatenate it
CPVlist = []
for file in CPV_files:
    CPV_ent = pd.read_csv(file, usecols=cpyv_col, dtype={'ageb': str}, na_values=['*','N/D'])
    CPVlist.append(CPV_ent)
CPV = pd.concat(CPVlist)

# Create a new CVE_MUN index
CPV['mun'] = CPV['entidad']*1000 + CPV['mun']

# Set names for the merging
CPV.rename(columns={'entidad':'CVE_ENT', 'loc':'CVE_LOC', 'mun':'CVE_MUN'}, inplace=True)

# Drop summary rows
CPV = CPV.loc[CPV['mza']!=0]

# Create missing age range
CPV['p_25a59'] = CPV['p_18ymas']-CPV['p_18a24']-CPV['p_60ymas']

# Organize columns
cols = CPV.columns.tolist()
cols = cols[:cols.index('p_60ymas')] + ['p_25a59'] + cols[cols.index('p_60ymas'):-1]
CPV = CPV[cols]

# Merge CPV with ZM dataframe
ZM_CPV = CPV.merge(ZM_2015, how='left', on=['CVE_MUN','CVE_ENT'])
ZM_CPV.reset_index(inplace=True, drop=True)

# Save CPV
pkls_path = pkls = r'D:\Tesis\ResEleCon-MX\pickles'
ZM_CPV.to_pickle(pkls + '\CPV2010_ZM.pkl')

del CPV
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1b962fef54d2> in <module>
#      42 # Save CPV
#      43 pkls_path = pkls = r'D:\Tesis\ResEleCon-MX\pickles'
# ---> 44 ZM_CPV.to_pickle(pkls + '\CPV2010_ZM.pkl')
#      45
#      46 del CPV
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_pickle(self, path, compression, protocol)
#    2723         from pandas.io.pickle import to_pickle
#    2724
# -> 2725         to_pickle(self, path, compression=compression, protocol=protocol)
#    2726
#    2727     def to_clipboard(
#
# ~\anaconda3\lib\site-packages\pandas\io\pickle.py in to_pickle(obj, filepath_or_buffer, compression, protocol)
#      86         protocol = pickle.HIGHEST_PROTOCOL
#      87     try:
# ---> 88         f.write(pickle.dumps(obj, protocol=protocol))
#      89     finally:
#      90         f.close()
#
# KeyboardInterrupt:

# %%
pkls_path = pkls = r'D:\Tesis\ResEleCon-MX\pickles'
enigh = pd.read_pickle(pkls_path + '\enigh_fullMX_2016.pkl')
ZM_CPV = pd.read_pickle(pkls_path + '\CPV2010_ZM.pkl')

# %% [markdown]
# ### CPV

# %%
sample_estado = ZM_CPV[['CVE_ENT','tothog']].groupby('CVE_ENT').sum()
sample_zm = ZM_CPV[['CVE_ENT','CVE_ZM','tothog']].groupby(['CVE_ENT','CVE_ZM']).sum().reset_index()

sample = sample_estado.merge(sample_zm, on='CVE_ENT')
sample.rename(columns={'tothog_x':'estado_CVP', 'tothog_y':'ZM_CVP'}, inplace=True)

sample['ratio_CVP'] = sample['ZM_CVP']/sample['estado_CVP']

# %% [markdown]
# ### ENIGH

# %%
sample_e1 = enigh[['estado','clase_hog']].groupby('estado').count()
sample_e2 = enigh[['estado','CVE_ZM','clase_hog']].groupby(['estado','CVE_ZM']).count().reset_index()

sample_e = sample_e1.merge(sample_e2, on='estado')
sample_e.rename(columns={'estado':'CVE_ENT','clase_hog_x':'estado_enigh', 'clase_hog_y':'ZM_enigh'}, inplace=True)

sample_e['ratio_enigh'] = sample_e['ZM_enigh']/sample_e['estado_enigh']

# %% [markdown]
# ### Both

# %%
S_comparison = sample.merge(sample_e, on=['CVE_ENT','CVE_ZM'])

# %%
S_comparison['enigh_cpv_e'] = S_comparison['estado_enigh']/S_comparison['estado_CVP']
S_comparison['enigh_cpv_zm'] = S_comparison['ZM_enigh']/S_comparison['ZM_CVP']

# %%
S_comparison
# Out:
#     CVE_ENT  estado_CVP  CVE_ZM     ZM_CVP  ratio_CVP  estado_enigh  ZM_enigh  \
# 0         1    237057.0    1.01   207901.0   0.877008          2382      1695
# 1         2    789668.0    2.01   109210.0   0.138299          3583       831
# 2         2    789668.0    2.02   231740.0   0.293465          3583      1162
# 3         2    789668.0    2.03   448718.0   0.568236          3583      1590
# 4         3    149748.0    3.01    62860.0   0.419772          2251       796
# 5         4    161662.0    4.01    64856.0   0.401183          1732       546
# 6         5    642275.0    5.01   186258.0   0.289997          3289      1061
# 7         5    642275.0    5.02    87501.0   0.136236          3289       318
# 8         5    642275.0    5.03    45781.0   0.071279          3289       146
# 9         5    642275.0    5.04   198641.0   0.309277          3289       946
# 10        6    157839.0    6.01    84313.0   0.534171          2700      1279
# 11        6    157839.0    6.02    32689.0   0.207103          2700       533
# 12        7    567158.0    7.01    61818.0   0.108996          1813       142
# 13        7    567158.0    7.02   163638.0   0.288523          1813       235
# 14        8    777135.0    8.01   229993.0   0.295950          3074       587
# 15        8    777135.0    8.02    43686.0   0.056214          3074       148
# 16        8    777135.0    8.03    28994.0   0.037309          3074        60
# 17        8    777135.0    8.04   339827.0   0.437282          3074       982
# 18        9   2376389.0    9.01  2376389.0   1.000000          1733      1733
# 19       10    277036.0    5.01    94108.0   0.339696          2010       548
# 20       10    277036.0   10.01   127053.0   0.458615          2010       570
# 21       11    887828.0   11.01   132297.0   0.149012          2435       247
# 22       11    887828.0   11.02    29660.0   0.033407          2435        73
# 23       11    887828.0   11.03   327026.0   0.368344          2435       621
# 24       11    887828.0   11.04    23544.0   0.026519          2435        43
# 25       11    887828.0   11.05    25346.0   0.028548          2435        91
# 26       11    887828.0   16.01    12827.0   0.014448          2435        48
# 27       11    887828.0   22.01     7955.0   0.008960          2435        49
# 28       12    480765.0   12.01   186071.0   0.387031          1696       508
# 29       12    480765.0   12.02    57064.0   0.118694          1696       137
# 30       13    370885.0    9.01    21935.0   0.059142          1821        76
# 31       13    370885.0   13.01   115885.0   0.312455          1821       287
